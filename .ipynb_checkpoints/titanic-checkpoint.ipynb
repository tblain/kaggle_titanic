# %% [markdown]
# ## Imports

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# ## Warning suppression

# %%
import warnings
warnings.filterwarnings(action="ignore", message="^internal gelsd")
warnings.simplefilter("ignore")

# %% [markdown]
# ## Telechargement du dataset

# %%
from sklearn.datasets import fetch_openml
data = pd.read_csv("train.csv")

# %%
X = data.drop('Survived', axis=1)
X = X.drop('PassengerId', axis=1)
y = data["Survived"]

# %% [markdown]
# ## Data exploration

# %%
X.shape
# Out:
# (891, 10)

# %%
y.shape
# Out:
# (891,)

# %%
X.describe()
# Out:
#            Pclass         Age       SibSp       Parch        Fare
# count  891.000000  714.000000  891.000000  891.000000  891.000000
# mean     2.308642   29.699118    0.523008    0.381594   32.204208
# std      0.836071   14.526497    1.102743    0.806057   49.693429
# min      1.000000    0.420000    0.000000    0.000000    0.000000
# 25%      2.000000   20.125000    0.000000    0.000000    7.910400
# 50%      3.000000   28.000000    0.000000    0.000000   14.454200
# 75%      3.000000   38.000000    1.000000    0.000000   31.000000
# max      3.000000   80.000000    8.000000    6.000000  512.329200

# %% [markdown]
# ## Training and test set creation

# %%
from sklearn.model_selection import StratifiedShuffleSplit

split = StratifiedShuffleSplit(n_splits=1, test_size=0.2, random_state=42)

for train_index, test_index in split.split(X, y):
    strat_train_set = data.loc[train_index]
    strat_test_set = data.loc[test_index]

# %%
strat_train_set.shape
# Out:
# (712, 12)

# %%
strat_test_set.shape
# Out:
# (179, 12)

# %% [markdown]
# ### Correlation

# %%
corr_matrix = strat_train_set.corr()
corr_matrix['Survived'].sort_values(ascending=False)
# Out:
# Survived       1.000000
# Fare           0.275499
# Parch          0.084178
# PassengerId    0.011892
# SibSp         -0.026115
# Age           -0.084268
# Pclass        -0.348007
# Name: Survived, dtype: float64

# %%
# from pandas.tools.plotting import scatter_matrix # For older versions of Pandas
from pandas.plotting import scatter_matrix

attributes = ["median_house_value", "median_income", "total_rooms",
              "housing_median_age"]
scatter_matrix(strat_train_set, figsize=(12, 8))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7f2b1eb08208>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f2b1eae05f8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f2b1ea2e9e8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f2b1ea48e80>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f2b1d1ef438>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f2b1d1969b0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f2b1d1bff28>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7f2b1d16c518>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f2b1d16c550>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f2b1d13cfd0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f2b1d0ec588>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f2b1d094b00>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f2b1d0c50b8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f2b1d06b630>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7f2b1d093ba8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f2b1d044160>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f2b1cfea6d8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f2b1d012c50>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f2b1cfc2208>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f2b1cf6a780>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f2b1cf90cf8>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7f2b1cf402b0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f2b1cee9828>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f2b1cf11da0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f2b1cec2358>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f2b1ce688d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f2b1ce90e48>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f2b1ce40400>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7f2b1cde8978>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f2b1ce0fef0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f2b1cdbf4a8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f2b1cd69a20>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f2b1cd8ff98>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f2b1cd3e550>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f2b1cce4ac8>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7f2b1cc98080>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f2b1ccbd5f8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f2b1cc63b70>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f2b1cc15128>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f2b1cc3c6a0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f2b1cbe4c18>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f2b1cb961d0>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7f2b1cbbb748>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f2b1cb63cc0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f2b1ef210f0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f2b1ec01898>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f2b1ed9f278>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f2b1ed91b70>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f2b1ed89b00>]],
#       dtype=object)

# %% [markdown]
# ## Features selection

# %%
from sklearn.base import BaseEstimator, TransformerMixin

def indices_of_top_k(arr, k):
    return np.sort(np.argpartition(np.array(arr), -k)[-k:])

class TopFeatureSelector(BaseEstimator, TransformerMixin):
    def __init__(self, feature_importances, k):
        self.feature_importances = feature_importances
        self.k = k
    def fit(self, X, y=None):
        self.feature_indices_ = indices_of_top_k(self.feature_importances, self.k)
        return self
    def transform(self, X):
        return X[:, self.feature_indices_]

# %% [markdown]
# ## Pipelines creation

# %%
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler

num_pipeline = Pipeline([
    ('imputer', SimpleImputer(strategy="median")),
    ('attribs_adder', CombinedAttributesAdder()),
    ('std_scaler', StandardScaler()),
])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-32-f3b7809326a7> in <module>
#       3
#       4 num_pipeline = Pipeline([
# ----> 5     ('imputer', SimpleImputer(strategy="median")),
#       6     ('attribs_adder', CombinedAttributesAdder()),
#       7     ('std_scaler', StandardScaler()),
#
# NameError: name 'SimpleImputer' is not defined

# %%
k=5
preparation_and_feature_selection_pipeline = Pipeline([
    ('preparation', full_pipeline),
    ('feature_selection', TopFeatureSelector(feature_importances, k))
])

# %% [markdown]
# ## Classifier creation and training

# %%
from sklearn.linear_model import SGDClassifier

sgd_clf = SGDClassifier(random_state=42)
sgd_clf.fit(X_train, y_train)
# Out:
# SGDClassifier(alpha=0.0001, average=False, class_weight=None,
#        early_stopping=False, epsilon=0.1, eta0=0.0, fit_intercept=True,
#        l1_ratio=0.15, learning_rate='optimal', loss='hinge', max_iter=None,
#        n_iter=None, n_iter_no_change=5, n_jobs=None, penalty='l2',
#        power_t=0.5, random_state=42, shuffle=True, tol=None,
#        validation_fraction=0.1, verbose=0, warm_start=False)

# %%
import numpy as np
